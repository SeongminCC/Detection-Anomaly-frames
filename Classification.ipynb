# %% [markdown]
# <a href="https://colab.research.google.com/github/SeongminCC/Detection-Anomaly-frames/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module install

# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0)
# Collecting huggingface-hub (from timm)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.1 MB/s eta 0:00:00
# Collecting safetensors (from timm)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: safetensors, huggingface-hub, timm
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 timm-0.9.2

# %%
# %cd /content/drive/MyDrive/bora_project
# !pwd
# Out:
# /content/drive/MyDrive/bora_project
# /content/drive/MyDrive/bora_project

# %% [markdown]
# # Module import

# %%
import os
import shutil

import random
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2


from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

import timm
# from pytorch_image_models.timm.models.vision_transformer import vit_base_patch8_224  # 추가 작업 필요

# %% [markdown]
# # setting

# %%
random_seed= 42
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.backends.cudnn.deterministic = True

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu") # select device for training, i.e. gpu or cpu
print(DEVICE)
# Out:
# cuda

# %% [markdown]
# ============================ 데이터 전처리를 위한 코드이니 아래 코드는 실행하지 마세요 ============================

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## data path

# %%
train_path = "/content/drive/MyDrive/bora_project/data/train"
test_path = "/content/drive/MyDrive/bora_project/data/test"

label_path = "/content/drive/MyDrive/bora_project/data/data.csv"

# %%
df = pd.read_csv(label_path, index_col=0)
df
# Out:
#     image_path  class
# 0       44.jpg      1
# 1      478.jpg      0
# 2      244.jpg      1
# 3      161.jpg      1
# 4       79.jpg      1
# ..         ...    ...
# 663    323.jpg      1
# 664    555.jpg      0
# 665    412.jpg      0
# 666    168.jpg      1
# 667    390.jpg      0
#
# [668 rows x 2 columns]

# %% [markdown]
# ## data split
# - 90:10 의 비율로 split 진행 (데이터의 수가 부족한 관계로 train data를 최대한 확보)
#     - train : 0 ~ 333.jpg
#     - test : 334 ~ 667.jpg
#
#
# 각각 랜덤하게 10% 만큼 추출하여 test directory로 move
# - train data : 601개
# - test data : 67개

# %%
# stratify 인자를 사용하여 label 비율이 동일하도록 설정
train_df, test_df = train_test_split(df, test_size=0.10, stratify=df['class'], random_state=1201)

# %%
val_df, test_df = train_test_split(test_df, test_size=0.50, stratify=test_df['class'], random_state=1201)

# %%
print(f"length of train data : {len(train_df)}")
print(f"length of val data : {len(val_df)}")
print(f"length of test data : {len(test_df)}")
# Out:
# length of train data : 601
# length of val data : 33
# length of test data : 34

# %%
print("#### train data ####")
print(train_df['class'].value_counts())
print()

print("#### test data ####")
print(val_df['class'].value_counts())
print()

print("#### test data ####")
print(test_df['class'].value_counts())
# Out:
# #### train data ####
# 0    301
# 1    300
# Name: class, dtype: int64
#
# #### test data ####
# 1    17
# 0    16
# Name: class, dtype: int64
#
# #### test data ####
# 0    17
# 1    17
# Name: class, dtype: int64

# %% [markdown]
# ## generate train & test csv file

# %%
train_df.to_csv("/content/drive/MyDrive/bora_project/data/train.csv")
val_df.to_csv("/content/drive/MyDrive/bora_project/data/validation.csv")
test_df.to_csv("/content/drive/MyDrive/bora_project/data/test.csv")

# %% [markdown]
# ============================ 데이터 전처리를 위한 코드이니 위 코드는 실행하지 마세요 ============================

# %% [markdown]
# # Data load

# %%
# directory path
main_path = "/content/drive/MyDrive/bora_project"
train_path = "/content/drive/MyDrive/bora_project/data/train"
checkpoint_path = "/content/drive/MyDrive/bora_project/checkpoints"

# csv path
train_csv_path = "/content/drive/MyDrive/bora_project/data/train.csv"
val_csv_path = "/content/drive/MyDrive/bora_project/data/validation.csv"
test_csv_path = "/content/drive/MyDrive/bora_project/data/test.csv"

# %%
train_df = pd.read_csv(train_csv_path, index_col = 0)
val_df = pd.read_csv(val_csv_path, index_col = 0)
test_df = pd.read_csv(test_csv_path, index_col = 0)

# %%
train_df
# Out:
#     image_path  class
# 649    392.jpg      0
# 238    605.jpg      0
# 249     93.jpg      1
# 264    250.jpg      1
# 208    303.jpg      1
# ..         ...    ...
# 3      161.jpg      1
# 258    646.jpg      0
# 247    396.jpg      0
# 426    326.jpg      1
# 319    100.jpg      1
#
# [601 rows x 2 columns]

# %%
val_df
# Out:
#     image_path  class
# 513    573.jpg      0
# 573    253.jpg      1
# 111     49.jpg      1
# 2      244.jpg      1
# 108    145.jpg      1
# 291    288.jpg      1
# 559    577.jpg      0
# 666    168.jpg      1
# 462    123.jpg      1
# 223    509.jpg      0
# 277     38.jpg      1
# 414    284.jpg      1
# 501    636.jpg      0
# 389     68.jpg      1
# 301    642.jpg      0
# 255     96.jpg      1
# 97     132.jpg      1
# 323    212.jpg      1
# 496    314.jpg      1
# 660    628.jpg      0
# 495    459.jpg      0
# 634    273.jpg      1
# 32     574.jpg      0
# 464    595.jpg      0
# 667    390.jpg      0
# 266    438.jpg      0
# 198    593.jpg      0
# 295    520.jpg      0
# 98     350.jpg      0
# 197    493.jpg      0
# 138    427.jpg      0
# 420    333.jpg      1
# 353    170.jpg      1

# %%
test_df
# Out:
#     image_path  class
# 16     375.jpg      0
# 329    152.jpg      1
# 148    631.jpg      0
# 211    372.jpg      0
# 346    310.jpg      1
# 50     131.jpg      1
# 423    664.jpg      0
# 640    512.jpg      0
# 382    550.jpg      0
# 325    142.jpg      1
# 544    424.jpg      0
# 456    190.jpg      1
# 70      33.jpg      1
# 28     620.jpg      0
# 80     397.jpg      0
# 73     193.jpg      1
# 409    490.jpg      0
# 652    301.jpg      1
# 191     62.jpg      1
# 244    267.jpg      1
# 641    200.jpg      1
# 611    501.jpg      0
# 95     547.jpg      0
# 1      478.jpg      0
# 269    468.jpg      0
# 400    108.jpg      1
# 396     19.jpg      1
# 51     280.jpg      1
# 265    245.jpg      1
# 213    662.jpg      0
# 101     25.jpg      1
# 72     133.jpg      1
# 572    660.jpg      0
# 525    562.jpg      0

# %% [markdown]
# # custom datasets

# %% [markdown]
# ## visualize images (dolphin vs non dolphin)

# %%
i = random.randint(1, math.floor(len(train_df)/2))

fig, axs = plt.subplots(1,2, figsize = (40,20), dpi = 100)

dolphin_path = train_df.loc[train_df['class'] == 1].iloc[i]['image_path']
non_dolphin_path = train_df.loc[train_df['class'] == 0].iloc[i]['image_path']

dolphin_img = cv2.imread(os.path.join(train_path, dolphin_path))
non_dolphin_img = cv2.imread(os.path.join(train_path, non_dolphin_path))

axs[0].set_title(f"dolphin ({dolphin_path})", fontsize = 40)
axs[0].imshow(dolphin_img)
axs[1].set_title(f"non dolphin ({non_dolphin_path})", fontsize = 40)
axs[1].imshow(non_dolphin_img)

axs[0].axes.xaxis.set_visible(False)
axs[0].axes.yaxis.set_visible(False)
axs[1].axes.xaxis.set_visible(False)
axs[1].axes.yaxis.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## custom dataset

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, dataframe, train_path, transform=None):
        self.data = dataframe
        self.transform = transform
        self.train_path = train_path

        self.lst_input = list(self.data['image_path'])
        self.lst_label = list(self.data['class'])

    def __len__(self):
        return len(self.lst_input)

    def __getitem__(self, index):

        label = self.lst_label[index]
        img_input = cv2.imread(os.path.join(self.train_path, self.lst_input[0])) # H W C

        if self.transform:
            img_input = self.transform(img_input)

        return img_input, label

# %% [markdown]
# ## data transform

# %%
resize = 224, 224

transform_train = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(((resize))),
    transforms.ToTensor(),
    transforms.Normalize(mean=0.5, std=0.5)
])

transform_val = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(((resize))),
    transforms.ToTensor(),
    transforms.Normalize(mean=0.5, std=0.5)
])

# %% [markdown]
# ## Verify the correct application of the dataset

# %%
# 데이터셋 클래스 적용
train_datasets = Dataset(train_df, train_path, transform=transform_train)
print("My custom training-dataset has {} elements".format(len(train_datasets)))

val_datasets = Dataset(val_df, train_path, transform=transform_val)
print("My custom validation-dataset has {} elements".format(len(val_datasets)))

test_datasets = Dataset(test_df, train_path, transform=transform_val)
print("My custom test-dataset has {} elements".format(len(test_datasets)))
# Out:
# My custom training-dataset has 601 elements
# My custom validation-dataset has 33 elements
# My custom test-dataset has 34 elements

# %%
img, label = train_datasets.__getitem__(12)
print(f"Input shape : {img.shape} \nLabel : {label}")

img_np = img.numpy().transpose(1,2,0)

if label == 0:
    name = "non dolphin"
else:
    name = "dolphin"

plt.title(name)
plt.axis('off')
plt.imshow(img_np)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Input shape : torch.Size([3, 224, 224])
# Label : 1

# %% [markdown]
# **위 image는 normalize를 한 후 시각화를 한 결과이다. 직관적으로 보았을 때 전체적으로 흑색을 띄며 탐지해야하는 돌고래가 보이지 않음을 확인할 수 있음**
# - 단지 직관적으로 본 결과에서만 돌고래 픽셀 값이 사라진 것일 수도 있음. -> 여전히 돌고래의 픽셀 패턴은 존재
# - 만약 classification 결과가 좋지 않다면 다른 task로 접근할 필요가 있어보임(**object detection**  &  **image segmentation**)

# %% [markdown]
# ## Data Loader

# %%
BATCH_SIZE = 10

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=BATCH_SIZE, num_workers=2)
val_dataloader = torch.utils.data.DataLoader(val_datasets, batch_size=BATCH_SIZE, num_workers=2)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=BATCH_SIZE, num_workers=2)

# %% [markdown]
# # Model Load

# %%
def mk_model(model_name, num_classes=2):
    if model_name == 'resnet18':
        from torchvision import models
        import torch

        resnet18_pretrained = models.resnet18(pretrained=True)
        num_ftrs = resnet18_pretrained.fc.in_features
        resnet18_pretrained.fc = nn.Linear(num_ftrs, num_classes)

        resnet18_pretrained.to(DEVICE)

        net = resnet18_pretrained




    if model_name == 'wide_resnet50_2':
        from torchvision import models
        import torch

        wide_resnet50_2 = models.wide_resnet50_2(pretrained=True)

        num_ftr = wide_resnet50_2.fc.in_features
        wide_resnet50_2.fc = nn.Linear(num_ftr, num_classes)

        wide_resnet50_2.to(DEVICE)

        net = wide_resnet50_2




    if model_name == 'EfficientNet_b4':
        from torchvision import models
        import torch
        import timm

        class EfficientNet_b4(nn.Module):
            def __init__(self, num_classes):
                super(EfficientNet_b4, self).__init__()
                self.efficient = timm.create_model(model_name='efficientnet_b4',
                    num_classes=num_classes,
                    pretrained=True
                    )

            def forward(self, x: torch.Tensor) -> torch.Tensor:
                return self.efficient(x)
        EfficientNet_b4 = EfficientNet_b4(50)
        EfficientNet_b4.to(DEVICE)

        net = EfficientNet_b4




    if model_name == 'visformer_small':
        from torchvision import models
        import torch
        import timm

        visformer_small = timm.create_model('visformer_small', num_classes=num_classes, pretrained=True)

        visformer_small.to(DEVICE)

        net = visformer_small




    if model_name == 'vit_small_patch8_224_dino':
        from torchvision import models
        import torch
        import timm

        vit_small_patch8_224_dino = timm.create_model('vit_small_patch8_224_dino', num_classes=num_classes, pretrained=True)

        vit_small_patch8_224_dino.to(DEVICE)

        net = vit_small_patch8_224_dino

    return net

# %% [markdown]
# # Early stopping class

# %%
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): validation loss가 개선된 후 기다리는 기간
                            Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력
                            Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화
                            Default: 0
            path (str): checkpoint저장 경로
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# # Train

# %% [markdown]
# ## train function

# %%
def train(model,
          model_name,
          train_dataloader,
          val_dataloader,
          optimizer,
          loss,
          epochs = 30,
          patience = 10,
          early_stopping = False,
          checkpoint_path = checkpoint_path):

    if early_stopping:
        earlystopping = EarlyStopping(patience=10, verbose=True, delta=0, path=f'{os.path.join(checkpoint_path, f"earlystopping_{model_name}.pth")}')

    for epoch in range(1, epochs+1):
        print(f"Train epoch : {epoch}")
        model.train()
        train_loss = 0 # train loss 값
        correct = 0 # 맞힌 개수
        total = 0 # 총 데이터 수

        for batch_idx, (inputs, labels) in enumerate(train_dataloader):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()

            optimizer.step()
            train_loss += loss.item()
            _, predicted = outputs.max(1)

            total += labels.size(0)
            current_correct = (predicted == labels).sum().item()
            correct += current_correct

            # batch 가 10단위 일때마다 accuracy, loss 값 출력
            if batch_idx % 10 == 0:
                print('\nCurrent batch:', str(batch_idx))
                print('Current batch average train accuracy:', current_correct / labels.size(0))
                print('Current batch average train loss:', loss.item() / labels.size(0))

        # 훈련이 모두 끝난 후 accuracy, loss 값 출력
        print('\nTotal average train accuarcy:', correct / total)
        print('Total average train loss:', train_loss / total)


        # validation
        print(f"Validation epoch : {epoch}")
        model.eval()
        loss = 0
        correct = 0
        total = 0
        valid_losses = [] # validation loss값을 구하기 위해 각 batch의 loss값 저장

        with torch.no_grad():
            for batch_idx, (inputs, labels) in enumerate(val_dataloader):
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                total += labels.size(0)

                outputs = model(inputs)
                loss += criterion(outputs, labels).item()

                valid_losses.append(loss)

                _, predicted = outputs.max(1)
                correct += (predicted == labels).sum().item()

            print('\nTotal average test accuarcy:', correct / total)
            print('Total average test loss:', loss / total)

            valid_loss = np.average(valid_losses)

            if early_stopping:
                earlystopping(valid_loss, model)

                if earlystopping.early_stop:
                    print("Early stopping !!")
                    break

    state = {
        'model' : model.state_dict()
    }
    if not os.path.isdir(os.path.join(checkpoint_path, "final")):
        os.mkdir(os.path.join(checkpoint_path, "final"))
    torch.save(state, os.path.join(checkpoint_path, f"final/ckpt_{model_name}.pth"))
    print("Model saved!!")

# %% [markdown]
# ## training

# %%
models = ['resnet18', 'wide_resnet50_2', 'EfficientNet_b4', 'visformer_small', 'vit_small_patch8_224_dino']

for model_name in models:
    model = mk_model(model_name)
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay = 1e-8)
    criterion = nn.CrossEntropyLoss()

    print(f"##### model name : {model_name} #####")

    train(
        model = model,
        model_name = model_name,
        train_dataloader = train_dataloader,
        val_dataloader = val_dataloader,
        optimizer = optimizer,
        loss = criterion,
        epochs = 100,
        patience = 5,
        early_stopping = True,
        checkpoint_path = checkpoint_path
    )
    print("##### THE END #####\n\n\n\n")
# Out:
# ##### model name : resnet18 #####
# Train epoch : 1
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.091642826795578
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06589263677597046
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0678782343864441
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.0702158272266388
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06968145370483399
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06501644253730773
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8636941909790039
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.0717740690648655
# Validation epoch : 1
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.0862287517749902
# Validation loss decreased (inf --> 1.800369).  Saving model ...
# Train epoch : 2
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.0716977834701538
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0636285424232483
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0673094391822815
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06979420781135559
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06911824941635132
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06435506939888
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8293773531913757
#
# Total average train accuarcy: 0.5074875207986689
# Total average train loss: 0.07152519805260783
# Validation epoch : 2
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08372349630702626
# Validation loss decreased (1.800369 --> 1.720210).  Saving model ...
# Train epoch : 3
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07256821990013122
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06354383826255798
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06736727952957153
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06973929405212402
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06863332986831665
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06461412310600281
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7880846261978149
#
# Total average train accuarcy: 0.5108153078202995
# Total average train loss: 0.07126806966476948
# Validation epoch : 3
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.0843071901437008
# EarlyStopping counter: 1 out of 10
# Train epoch : 4
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07163535356521607
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0640256404876709
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06730200052261352
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07018502950668334
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06837751269340515
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06444440484046936
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7531431317329407
#
# Total average train accuarcy: 0.5041597337770383
# Total average train loss: 0.07111495247299779
# Validation epoch : 4
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08413955117716934
# EarlyStopping counter: 2 out of 10
# Train epoch : 5
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07079736590385437
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06466504335403442
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06737380623817443
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07066643238067627
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06843792796134948
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06411908268928528
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7411718368530273
#
# Total average train accuarcy: 0.5074875207986689
# Total average train loss: 0.07104901039659878
# Validation epoch : 5
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08381465890190819
# EarlyStopping counter: 3 out of 10
# Train epoch : 6
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07050523161888123
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0650140643119812
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06747093796730042
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07085475325584412
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06860342025756835
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06386617422103882
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.726186990737915
#
# Total average train accuarcy: 0.5108153078202995
# Total average train loss: 0.07101894168806155
# Validation epoch : 6
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08383622494610873
# EarlyStopping counter: 4 out of 10
# Train epoch : 7
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07007183432579041
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06544650197029114
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06756110191345215
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07084433436393738
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0687680721282959
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0638090968132019
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7121742367744446
#
# Total average train accuarcy: 0.5074875207986689
# Total average train loss: 0.07096546332967063
# Validation epoch : 7
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08403067155317827
# EarlyStopping counter: 5 out of 10
# Train epoch : 8
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.06960704922676086
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06564627885818482
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06759419441223144
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07082383632659912
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0688050627708435
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06380303502082825
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7197872400283813
#
# Total average train accuarcy: 0.5108153078202995
# Total average train loss: 0.07095061145884027
# Validation epoch : 8
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08401965191870024
# EarlyStopping counter: 6 out of 10
# Train epoch : 9
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.0698159396648407
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06562129855155945
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0675563633441925
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07075278759002686
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06887282133102417
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06388251781463623
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7009144425392151
#
# Total average train accuarcy: 0.5108153078202995
# Total average train loss: 0.07092573856950402
# Validation epoch : 9
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08415796901240494
# EarlyStopping counter: 7 out of 10
# Train epoch : 10
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06920532584190368
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06582980751991271
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06766163110733033
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07086797952651977
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06905125379562378
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0637632966041565
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6866776943206787
#
# Total average train accuarcy: 0.5158069883527454
# Total average train loss: 0.07090387368162539
# Validation epoch : 10
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08406875169638431
# EarlyStopping counter: 8 out of 10
# Train epoch : 11
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06877890825271607
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06612012982368469
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06770113706588746
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07082141041755677
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06915351152420043
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06375264525413513
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.686631977558136
#
# Total average train accuarcy: 0.519134775374376
# Total average train loss: 0.07088029503623976
# Validation epoch : 11
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08398711861986102
# EarlyStopping counter: 9 out of 10
# Train epoch : 12
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06875491142272949
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06611722111701965
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06770835518836975
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07080825567245483
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06922417283058166
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06381064653396606
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6801578402519226
#
# Total average train accuarcy: 0.519134775374376
# Total average train loss: 0.07087055359426235
# Validation epoch : 12
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08404260331934149
# EarlyStopping counter: 10 out of 10
# Early stopping !!
# Model saved!!
# ##### THE END #####
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Wide_ResNet50_2_Weights.IMAGENET1K_V1`. You can also use `weights=Wide_ResNet50_2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/wide_resnet50_2-95faca4d.pth" to /root/.cache/torch/hub/checkpoints/wide_resnet50_2-95faca4d.pth
# 100%|██████████| 132M/132M [00:00<00:00, 176MB/s]
# ##### model name : wide_resnet50_2 #####
# Train epoch : 1
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07758973836898804
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06729647517204285
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06766641139984131
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07001701593399048
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07134400606155396
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06784263849258423
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8262859582901001
#
# Total average train accuarcy: 0.5008319467554077
# Total average train loss: 0.07184078897692003
# Validation epoch : 1
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08363085985183716
# Validation loss decreased (inf --> 1.714449).  Saving model ...
# Train epoch : 2
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06810837984085083
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06334294080734253
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06760931015014648
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06989920139312744
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06936172246932984
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06452252268791199
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7627699971199036
#
# Total average train accuarcy: 0.5008319467554077
# Total average train loss: 0.07153013175021788
# Validation epoch : 2
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08360043980858543
# Validation loss decreased (1.714449 --> 1.708221).  Saving model ...
# Train epoch : 3
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07048924565315247
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06453710198402404
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06741265058517457
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07024626731872559
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06884821057319641
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06425381898880005
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7490887641906738
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.07106926506648643
# Validation epoch : 3
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.0836663083596663
# Validation loss decreased (1.708221 --> 1.705033).  Saving model ...
# Train epoch : 4
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07051616907119751
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06494995951652527
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06747744083404542
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07055466771125793
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06876536607742309
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06408722996711731
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.733144223690033
#
# Total average train accuarcy: 0.5108153078202995
# Total average train loss: 0.07099515725292897
# Validation epoch : 4
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08379797863237785
# Validation loss decreased (1.705033 --> 1.703571).  Saving model ...
# Train epoch : 5
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07020359039306641
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06523444056510926
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06759761571884156
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07073581814765931
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06903117895126343
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06391115784645081
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6895925998687744
#
# Total average train accuarcy: 0.5124792013311148
# Total average train loss: 0.07093743645212615
# Validation epoch : 5
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08360881877667976
# EarlyStopping counter: 1 out of 10
# Train epoch : 6
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06877421140670777
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06580551862716674
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06766265630722046
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07066715955734253
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06917482018470764
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06397504806518554
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.691864013671875
#
# Total average train accuarcy: 0.519134775374376
# Total average train loss: 0.0708803672362088
# Validation epoch : 6
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08361102414853645
# EarlyStopping counter: 2 out of 10
# Train epoch : 7
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06884792447090149
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06599966287612916
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06783190965652466
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07070544362068176
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06961737871170044
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06415101885795593
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6531462669372559
#
# Total average train accuarcy: 0.5124792013311148
# Total average train loss: 0.07082780813813805
# Validation epoch : 7
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08361328731883656
# EarlyStopping counter: 3 out of 10
# Train epoch : 8
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06756726503372193
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06633580923080444
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06793357133865356
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07068728804588317
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06999901533126832
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06453129053115844
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6247496604919434
#
# Total average train accuarcy: 0.5058236272878536
# Total average train loss: 0.07075289769497965
# Validation epoch : 8
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08363520737850305
# EarlyStopping counter: 4 out of 10
# Train epoch : 9
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06656925678253174
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0662643551826477
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06802632212638855
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07059571743011475
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07031605243682862
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06477526426315308
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6182534694671631
#
# Total average train accuarcy: 0.502495840266223
# Total average train loss: 0.07073366870102589
# Validation epoch : 9
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08362768816225456
# EarlyStopping counter: 5 out of 10
# Train epoch : 10
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06636421084403991
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06610261201858521
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06812515258789062
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07058125734329224
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07045633792877197
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06465157270431518
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6312589049339294
#
# Total average train accuarcy: 0.502495840266223
# Total average train loss: 0.0707765454658851
# Validation epoch : 10
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08360887838132454
# EarlyStopping counter: 6 out of 10
# Train epoch : 11
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06679907441139221
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06618263125419617
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06822201013565063
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.0705302119255066
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07063578367233277
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06518838405609131
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6135403513908386
#
# Total average train accuarcy: 0.502495840266223
# Total average train loss: 0.07073485067799166
# Validation epoch : 11
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08364533474951079
# EarlyStopping counter: 7 out of 10
# Train epoch : 12
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06616110801696777
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06584523916244507
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06809636950492859
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07063997387886048
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07044576406478882
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06497726440429688
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6166068911552429
#
# Total average train accuarcy: 0.502495840266223
# Total average train loss: 0.0707634347250775
# Validation epoch : 12
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08366365685607448
# EarlyStopping counter: 8 out of 10
# Train epoch : 13
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06626712679862976
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06598011255264283
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06810575127601623
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07061148285865784
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07047385573387147
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06495999097824097
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6078206300735474
#
# Total average train accuarcy: 0.502495840266223
# Total average train loss: 0.07074252956123796
# Validation epoch : 13
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08370704542506825
# EarlyStopping counter: 9 out of 10
# Train epoch : 14
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06601265668869019
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06607095599174499
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06823058724403382
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07051377892494201
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07077643275260925
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06539987325668335
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6051257252693176
#
# Total average train accuarcy: 0.502495840266223
# Total average train loss: 0.07072651396178564
# Validation epoch : 14
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08367076787081631
# EarlyStopping counter: 10 out of 10
# Early stopping !!
# Model saved!!
# ##### THE END #####
# Downloading model.safetensors:   0%|          | 0.00/77.9M [00:00<?, ?B/s]
# ##### model name : EfficientNet_b4 #####
# Train epoch : 1
#
# Current batch: 0
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.33741154670715334
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06887568235397339
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.08145338296890259
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.0711111605167389
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.08273612856864929
#
# Current batch: 50
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.072102290391922
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8614855408668518
#
# Total average train accuarcy: 0.49584026622296173
# Total average train loss: 0.09273398686169387
# Validation epoch : 1
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.27080107457710034
# Validation loss decreased (inf --> 5.482710).  Saving model ...
# Train epoch : 2
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0650917649269104
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06935613751411437
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06802864670753479
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07214812636375427
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06925441026687622
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0655163586139679
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9628959894180298
#
# Total average train accuarcy: 0.4841930116472546
# Total average train loss: 0.07451903066301901
# Validation epoch : 2
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.28309447115117853
# EarlyStopping counter: 1 out of 10
# Train epoch : 3
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07152915596961976
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06669870615005494
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06784344911575317
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07140007615089417
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06898003816604614
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06564997434616089
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9441903829574585
#
# Total average train accuarcy: 0.4841930116472546
# Total average train loss: 0.07322166485715031
# Validation epoch : 3
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.2925435124021588
# EarlyStopping counter: 2 out of 10
# Train epoch : 4
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07199761271476746
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06527894735336304
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06791359186172485
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07008208632469178
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06940133571624756
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06533960103988648
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9245344400405884
#
# Total average train accuarcy: 0.4908485856905158
# Total average train loss: 0.07275549603777995
# Validation epoch : 4
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.29594205365036474
# EarlyStopping counter: 3 out of 10
# Train epoch : 5
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07254264354705811
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0638356328010559
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.068890780210495
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06961690783500671
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07061254382133483
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06372319459915161
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9602497816085815
#
# Total average train accuarcy: 0.4841930116472546
# Total average train loss: 0.07269934499124918
# Validation epoch : 5
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.3124243779615922
# EarlyStopping counter: 4 out of 10
# Train epoch : 6
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07505494952201844
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06283038258552551
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06937484741210938
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06964449286460876
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.0707809567451477
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0634982407093048
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9563387632369995
#
# Total average train accuarcy: 0.47088186356073214
# Total average train loss: 0.07267151041554532
# Validation epoch : 6
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.30799925688541296
# EarlyStopping counter: 5 out of 10
# Train epoch : 7
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07545209527015687
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06260944604873657
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06947660446166992
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06968476176261902
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07098535299301148
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06346248984336852
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9435750842094421
#
# Total average train accuarcy: 0.4908485856905158
# Total average train loss: 0.07256486263132333
# Validation epoch : 7
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.302740833976052
# EarlyStopping counter: 6 out of 10
# Train epoch : 8
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07583491802215576
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06238487362861633
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06948840022087097
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06959605813026429
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07085679769515991
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06345022916793823
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9277459383010864
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.07247223869933067
# Validation epoch : 8
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.30015097242413147
# EarlyStopping counter: 7 out of 10
# Train epoch : 9
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.0756350040435791
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06245808601379395
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06920186281204224
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06958540678024291
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.0707144021987915
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0635794758796692
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9152200222015381
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.0723687114810785
# Validation epoch : 9
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.29974134763081867
# EarlyStopping counter: 8 out of 10
# Train epoch : 10
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.0754872977733612
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06243973970413208
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06904703378677368
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.0695490837097168
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07035971879959106
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06382209062576294
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8881217241287231
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.07225971491681954
# Validation epoch : 10
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.31982138662627246
# EarlyStopping counter: 9 out of 10
# Train epoch : 11
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07484826445579529
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06261327266693115
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06875718235969544
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06950139999389648
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.0699729561805725
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06406576633453369
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8719941973686218
#
# Total average train accuarcy: 0.5041597337770383
# Total average train loss: 0.07212217734776401
# Validation epoch : 11
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.32056246381817444
# EarlyStopping counter: 10 out of 10
# Early stopping !!
# Model saved!!
# ##### THE END #####
# Downloading model.safetensors:   0%|          | 0.00/161M [00:00<?, ?B/s]
# ##### model name : visformer_small #####
# Train epoch : 1
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.06956002712249756
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06928931474685669
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06928321123123168
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06931764483451844
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06953938603401184
#
# Current batch: 50
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.06958180665969849
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.694962203502655
#
# Total average train accuarcy: 0.4841930116472546
# Total average train loss: 0.07039015652137667
# Validation epoch : 1
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.09102755243127997
# Validation loss decreased (inf --> 1.924346).  Saving model ...
# Train epoch : 2
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.06934749484062194
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06902804970741272
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06944654583930969
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06931474208831787
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06937571167945862
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06929045915603638
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6885011792182922
#
# Total average train accuarcy: 0.47254575707154745
# Total average train loss: 0.07037844227475057
# Validation epoch : 2
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.090044202226581
# Validation loss decreased (1.924346 --> 1.784225).  Saving model ...
# Train epoch : 3
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06909270882606507
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06880275011062623
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06955628991127014
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06931620240211486
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06928900480270386
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06913496255874634
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6850029826164246
#
# Total average train accuarcy: 0.49916805324459235
# Total average train loss: 0.07037840260443791
# Validation epoch : 3
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.12049306703336311
# EarlyStopping counter: 1 out of 10
# Train epoch : 4
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06895586252212524
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06868180036544799
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.0696171760559082
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06931796073913574
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06924211382865905
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06905018091201783
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6830857992172241
#
# Total average train accuarcy: 0.49916805324459235
# Total average train loss: 0.07037932702189872
# Validation epoch : 4
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08367984222643303
# Validation loss decreased (1.784225 --> 1.717787).  Saving model ...
# Train epoch : 5
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06888121366500854
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06861623525619506
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06965083479881287
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.0693192183971405
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06921632885932923
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06900344491004944
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6820302605628967
#
# Total average train accuarcy: 0.49916805324459235
# Total average train loss: 0.0703800754023471
# Validation epoch : 5
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08714705344402429
# EarlyStopping counter: 1 out of 10
# Train epoch : 6
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06884028315544129
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0685807228088379
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06966930031776428
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06932000517845154
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06920199394226074
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06897751092910767
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6814494132995605
#
# Total average train accuarcy: 0.49916805324459235
# Total average train loss: 0.07038051524693875
# Validation epoch : 6
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08401953270941069
# EarlyStopping counter: 2 out of 10
# Train epoch : 7
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06881784200668335
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06856169700622558
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06967931985855103
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06932047009468079
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06919393539428711
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06896308660507203
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6811310052871704
#
# ...
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06918004751205445
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06894187927246094
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6807903051376343
#
# Total average train accuarcy: 0.49916805324459235
# Total average train loss: 0.07037941826361785
# Validation epoch : 21
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08394099907441573
# EarlyStopping counter: 8 out of 10
# Train epoch : 22
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06879390478134155
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06855327486991883
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06968539357185363
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06932108402252198
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0691797375679016
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06894154548645019
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6807911992073059
#
# Total average train accuarcy: 0.49916805324459235
# Total average train loss: 0.07037930926943381
# Validation epoch : 22
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08416184331431534
# EarlyStopping counter: 9 out of 10
# Train epoch : 23
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0687940239906311
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.0685540795326233
#
# Current batch: 20
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06968505382537842
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06932108998298644
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06917942166328431
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06894124150276185
#
# Current batch: 60
# Current batch average train accuracy: 1.0
# Current batch average train loss: 0.6807923913002014
#
# Total average train accuarcy: 0.49916805324459235
# Total average train loss: 0.07037920672167558
# Validation epoch : 23
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08443040558786104
# EarlyStopping counter: 10 out of 10
# Early stopping !!
# Model saved!!
# ##### THE END #####
# /usr/local/lib/python3.10/dist-packages/timm/models/_factory.py:114: UserWarning: Mapping deprecated model name vit_small_patch8_224_dino to current vit_small_patch8_224.dino.
#   model = create_fn(
# Downloading model.safetensors:   0%|          | 0.00/86.7M [00:00<?, ?B/s]
# ##### model name : vit_small_patch8_224_dino #####
# Train epoch : 1
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.1251470923423767
#
# Current batch: 10
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.2113874912261963
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0682881236076355
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07939327955245971
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06977626085281372
#
# Current batch: 50
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07297061085700988
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.7748820185661316
#
# Total average train accuarcy: 0.4841930116472546
# Total average train loss: 0.10827584125832988
# Validation epoch : 1
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.1036928856011593
# Validation loss decreased (inf --> 2.018406).  Saving model ...
# Train epoch : 2
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06380079388618469
#
# Current batch: 10
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07170882821083069
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06777024865150452
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07426895499229431
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07402729988098145
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06487759947776794
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8524819612503052
#
# Total average train accuarcy: 0.46089850249584025
# Total average train loss: 0.08168048202098904
# Validation epoch : 2
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08410234162301729
# Validation loss decreased (2.018406 --> 1.703898).  Saving model ...
# Train epoch : 3
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06382777094841004
#
# Current batch: 10
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07437841892242432
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.067942214012146
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07291908264160156
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07364382743835449
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06412667036056519
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8935993909835815
#
# Total average train accuarcy: 0.480865224625624
# Total average train loss: 0.07477410204597003
# Validation epoch : 3
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.0836656978636077
# EarlyStopping counter: 1 out of 10
# Train epoch : 4
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06530780196189881
#
# Current batch: 10
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07374966740608216
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06801211237907409
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07304002642631531
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07073203325271607
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06402695178985596
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9623974561691284
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.07422544605125009
# Validation epoch : 4
#
# Total average test accuarcy: 0.5151515151515151
# Total average test loss: 0.08385075402982307
# EarlyStopping counter: 2 out of 10
# Train epoch : 5
#
# Current batch: 0
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06859501004219055
#
# Current batch: 10
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07044298052787781
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0676458477973938
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07272930145263672
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06874545216560364
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06506696343421936
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.967960000038147
#
# Total average train accuarcy: 0.5041597337770383
# Total average train loss: 0.07359066650197034
# Validation epoch : 5
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08451658306699811
# EarlyStopping counter: 3 out of 10
# Train epoch : 6
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07099896669387817
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06694619655609131
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06730282902717591
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.07108972668647766
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06839151382446289
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06579378843307496
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9321157932281494
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.0729908853918066
# Validation epoch : 6
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08461549787810355
# EarlyStopping counter: 4 out of 10
# Train epoch : 7
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07128545641899109
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06523321866989136
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06763209700584412
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06977598071098327
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06899716854095458
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06498712301254272
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9320077896118164
#
# Total average train accuarcy: 0.49750415973377704
# Total average train loss: 0.07266206838525274
# Validation epoch : 7
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08496303088737256
# EarlyStopping counter: 5 out of 10
# Train epoch : 8
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07222257852554322
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06395139694213867
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06815609931945801
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06942811012268066
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06958234310150146
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06435203552246094
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9435006380081177
#
# Total average train accuarcy: 0.47088186356073214
# Total average train loss: 0.0725667270368427
# Validation epoch : 8
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08526401086287065
# EarlyStopping counter: 6 out of 10
# Train epoch : 9
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.0729819655418396
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06353925466537476
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06788748502731323
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06941147446632386
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06968585848808288
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06394261121749878
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9443562626838684
#
# Total average train accuarcy: 0.4841930116472546
# Total average train loss: 0.0724501756582403
# Validation epoch : 9
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08568443854649861
# EarlyStopping counter: 7 out of 10
# Train epoch : 10
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07393907904624938
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06269733905792237
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06929923295974731
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06947528123855591
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.07076111435890198
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06324477791786194
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.9122061133384705
#
# Total average train accuarcy: 0.4908485856905158
# Total average train loss: 0.07232004949534793
# Validation epoch : 10
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.0864040038802407
# EarlyStopping counter: 8 out of 10
# Train epoch : 11
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.07546590566635132
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.062300318479537965
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06896361112594604
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06933207511901855
#
# Current batch: 40
# Current batch average train accuracy: 0.4
# Current batch average train loss: 0.06941057443618774
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06434155106544495
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.8359518051147461
#
# Total average train accuarcy: 0.5041597337770383
# Total average train loss: 0.07195121664770827
# Validation epoch : 11
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08536206772833159
# EarlyStopping counter: 9 out of 10
# Train epoch : 12
#
# Current batch: 0
# Current batch average train accuracy: 0.3
# Current batch average train loss: 0.0731932282447815
#
# Current batch: 10
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06293026804924011
#
# Current batch: 20
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.06815671324729919
#
# Current batch: 30
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.06937710046768189
#
# Current batch: 40
# Current batch average train accuracy: 0.6
# Current batch average train loss: 0.0685749351978302
#
# Current batch: 50
# Current batch average train accuracy: 0.7
# Current batch average train loss: 0.06499177813529969
#
# Current batch: 60
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.801336407661438
#
# Total average train accuarcy: 0.5174708818635607
# Total average train loss: 0.07159318424104255
# Validation epoch : 12
#
# Total average test accuarcy: 0.48484848484848486
# Total average test loss: 0.08489215554613055
# EarlyStopping counter: 10 out of 10
# Early stopping !!
# Model saved!!
# ##### THE END #####

# %% [markdown]
# # Test

# %%
models = ['resnet18', 'wide_resnet50_2', 'EfficientNet_b4', 'visformer_small', 'vit_small_patch8_224_dino']
acc_dict = {}
f1_dict = {}

for model_name in models:
    model = mk_model(model_name)
    state = torch.load(os.path.join(checkpoint_path, f"final/ckpt_{model_name}.pth"))
    model.load_state_dict(state['model'])

    size = (224,224)

    # 예측한 값
    pred_li = []

    for i in range(len(test_df)):
        test_images = list(test_df["image_path"])
        path_img = test_images[i]

        # eval 전 이미지 전처리
        img = cv2.imread(os.path.join(train_path, path_img))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

        # 양성형 이웃 보간 (2x2 픽셀 참조하여 보간)
        img = cv2.resize(img, size, interpolation = cv2.INTER_LINEAR)

        # eval
        model.eval()
        eval_image = img / 255.0
        eval_image = eval_image.astype(np.float32) # (224, 224, 3)
        eval_image = eval_image.transpose((2,0,1)) # (3, 224, 224)
        eval_image = torch.from_numpy(eval_image).unsqueeze(0) # Batch 채널 추가 (1, 3, 224, 224)
        eval_image = eval_image.to( device=DEVICE, dtype = torch.float32 )

        with torch.no_grad():
            pred = model(eval_image)

        pred = pred.cpu().numpy()
        pred = np.argmax(pred)
        pred_li.append(pred)


    # metric

    y_true = list(test_df['class'])
    y_pred = pred_li
    print("="*40)
    print(f"========== model name : {model_name} ==========")

    f1score = f1_score(y_true, y_pred, average = 'macro')
    f1_dict[model_name] = f1score
    print(f"f1 score (macro) : {f1score}")

    accuracy = accuracy_score(y_true, y_pred)
    acc_dict[model_name] = accuracy
    print(f"Accuracy : {accuracy}")
    print(f"========== THE END of {model_name} ==========")
    print("\n\n\n\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ========================================
# ========== model name : resnet18 ==========
# f1 score (macro) : 0.3333333333333333
# Accuracy : 0.5
# ========== THE END of resnet18 ==========
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Wide_ResNet50_2_Weights.IMAGENET1K_V1`. You can also use `weights=Wide_ResNet50_2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ========================================
# ========== model name : wide_resnet50_2 ==========
# f1 score (macro) : 0.3333333333333333
# Accuracy : 0.5
# ========== THE END of wide_resnet50_2 ==========
#
#
#
#
#
# ========================================
# ========== model name : EfficientNet_b4 ==========
# f1 score (macro) : 0.2346445824706694
# Accuracy : 0.4411764705882353
# ========== THE END of EfficientNet_b4 ==========
#
#
#
#
#
# ========================================
# ========== model name : visformer_small ==========
# f1 score (macro) : 0.5968379446640316
# Accuracy : 0.6470588235294118
# ========== THE END of visformer_small ==========
# /usr/local/lib/python3.10/dist-packages/timm/models/_factory.py:114: UserWarning: Mapping deprecated model name vit_small_patch8_224_dino to current vit_small_patch8_224.dino.
#   model = create_fn(
# ========================================
# ========== model name : vit_small_patch8_224_dino ==========
# f1 score (macro) : 0.3333333333333333
# Accuracy : 0.5
# ========== THE END of vit_small_patch8_224_dino ==========

# %% [markdown]
# # THE RESULT

# %%
# 딕셔너리를 DataFrame으로 변환
acc_df = pd.DataFrame(list(acc_dict.items()), columns=['Model', 'Accuracy'])
f1_df = pd.DataFrame(list(f1_dict.items()), columns=['Model', 'F1_score'])

# 두 DataFrame을 병합
results_df = pd.merge(acc_df, f1_df, on='Model')
display(results_df)

# 결과를 CSV 파일로 저장
results_df.to_csv(os.path.join(main_path, "classification.csv"), index=False)
# Out:
#                        Model  Accuracy  F1_score
# 0                   resnet18  0.500000  0.333333
# 1            wide_resnet50_2  0.500000  0.333333
# 2            EfficientNet_b4  0.441176  0.234645
# 3            visformer_small  0.647059  0.596838
# 4  vit_small_patch8_224_dino  0.500000  0.333333

# %% [markdown]
# 예상대로 결과가 좋진 않다. 큰 배경에 작은 object에 대해 분류를 진행했어야 했고 전체적인 feature를 추출해 분류를 진행하는 classification task는 좋은 결과를 얻지 못하였다. 다음으로 시도해볼 수 있는 것은 다음과 같다.
# - augmentation
#     - 데이터에 돌고래의 80%정도가 나오는 frame만을 추출하여 augmentation을 진행
#     - 지느러미만 나오는 frame도 모두 고려를 하다보니 성능적으로 떨어지는 것으로 보임
#
# - object detection
#     - 배경과 object가 존재하는 이미지에서 object를 탐지하는 것은 object detection이 적합
#
# - segmentation
#     - 픽셀단위로 분류를 진행하기 때문에 작은 픽셀정보만을 담고 있는 object를 탐지하기에 적합할 수 있음
